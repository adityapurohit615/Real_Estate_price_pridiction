# %% [markdown]
# # importing packages

# %%
import numpy as np
import pandas as pd

# %%
housing = pd.read_csv('Boston_Housing.csv')

# %%
housing.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-11078b9cf9fd> in <module>
# ----> 1 housing.DESCR
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'DESCR'

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV  Unnamed: 14
# 0  396.90   4.98  24.0          NaN
# 1  396.90   9.14  21.6          NaN
# 2  392.83   4.03  34.7          NaN
# 3  394.63   2.94  33.4          NaN
# 4  396.90   5.33  36.2          NaN

# %%
housing.drop('Unnamed: 14',axis = 1, inplace = True)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2, random_state = 42)
for train_index, test_index in split.split(housing, housing["CHAS"]):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
strat_train_set
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT  MEDV
# 254     16.4  392.89   6.57  21.9
# 348     17.0  390.94   5.99  24.5
# ...

# %%
X_train = strat_train_set.drop("MEDV", axis = 1)
y_train = strat_train_set["MEDV"].copy()

# %% [markdown]
# # Creating a pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
my_pipeline = Pipeline([
    ('imputer', SimpleImputer(missing_values = np.nan, strategy = 'mean')),
    ('std', StandardScaler())
])

# %%
final_tr_data = my_pipeline.fit_transform(X_train,y_train)

# %%
final_tr_data.shape
# Out:
# (404, 13)

# %%
X_train
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT
# 254     16.4  392.89   6.57
# 348     17.0  390.94   5.99
# 476     20.2  396.21  18.68
# ...

# %%
y_train
# Out:
# 254    21.9
# 348    24.5
# 476    16.7
# 321    23.1
# 326    23.0
#        ...
# 155    15.6
# 423    13.4
# 98     43.8
# 455    14.1
# 216    23.3
# Name: MEDV, Length: 404, dtype: float64

# %% [markdown]
# # fitting a mode

# %%
X_train.shape
# Out:
# (404, 13)

# %%
#from sklearn.ensemble import RandomForestClassifier
#model = RandomForestClassifier()
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_train
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT
# 254     16.4  392.89   6.57
# 348     17.0  390.94   5.99
# 476     20.2  396.21  18.68
# ...

# %%
strat_train_set.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
#
#      PTRATIO       B  LSTAT  MEDV
# 254     16.4  392.89   6.57  21.9
# 348     17.0  390.94   5.99  24.5
# 476     20.2  396.21  18.68  16.7
# 321     19.6  396.90   6.87  23.1
# 326     19.6  396.90   6.15  23.0

# %%
some_data = X_train.iloc[:5]

# %%
some_labels = y_train.iloc[:5]

# %%
preapared_data = my_pipeline.transform(some_data)

# %%
preapared_data.shape
# Out:
# (5, 13)

# %%
model.predict(preapared_data)
# Out:
# C:\Users\Aditya purohit\anaconda3\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([58.6464376 , 55.08652023, 28.03085482, 45.69821612, 44.82538239])

# %%
list(some_labels)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %%
##Evaluating the model

# %%
from sklearn.metrics import mean_squared_error
housing_predictions = model.predict(X_train)
mse = mean_squared_error(y_train,housing_predictions)
rmse = np.sqrt(mse)

# %%
mse
# Out:
# 23.32234607923367

# %%
rmse
# Out:
# 4.829321492635759

# %%
##Cross validation
